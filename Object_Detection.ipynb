# %% [markdown]
# <a href="https://colab.research.google.com/github/charitha-bot/Object_Detection/blob/main/Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# %%
model = YOLO('yolov8n.pt')

# %%
results = model("Car.jpg")
results[0].save("output_img.jpg")
# Out:
# image 1/1 /content/Car.jpg: 480x640 4 cars, 392.0ms
# Speed: 15.5ms preprocess, 392.0ms inference, 36.8ms postprocess per image at shape (1, 3, 480, 640)
# 'output_img.jpg'
